# %%
import matplotlib.pyplot as plt
from tkinter import *
import nltk
nltk.download('all')

from nltk.book import *
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\abc.zip.
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping taggers\averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers\averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping grammars\basque_grammars.zip.
# [nltk_data]    | Downloading package bcp47 to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\biocreative_ppi.zip.
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping models\bllip_wsj_no_aux.zip.
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping grammars\book_grammars.zip.
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\brown_tei.zip.
# [nltk_data]    | Downloading package cess_cat to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\cess_cat.zip.
# [nltk_data]    | Downloading package cess_esp to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\cess_esp.zip.
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\chat80.zip.
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\city_database.zip.
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\cmudict.zip.
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\comparative_sentences.zip.
# [nltk_data]    | Downloading package comtrans to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\conll2002.zip.
# [nltk_data]    | Downloading package conll2007 to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package crubadan to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\crubadan.zip.
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\dependency_treebank.zip.
# [nltk_data]    | Downloading package dolch to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\dolch.zip.
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\europarl_raw.zip.
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package floresta to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\floresta.zip.
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\framenet_v15.zip.
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\framenet_v17.zip.
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\gazetteers.zip.
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package ieer to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\ieer.zip.
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package indian to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\indian.zip.
# [nltk_data]    | Downloading package jeita to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package kimmo to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\kimmo.zip.
# [nltk_data]    | Downloading package knbc to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping grammars\large_grammars.zip.
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\lin_thesaurus.zip.
# [nltk_data]    | Downloading package mac_morpho to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\mac_morpho.zip.
# [nltk_data]    | Downloading package machado to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package masc_tagged to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping chunkers\maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping taggers\maxent_treebank_pos_tagger.zip.
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping models\moses_sample.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\movie_reviews.zip.
# [nltk_data]    | Downloading package mte_teip5 to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\mte_teip5.zip.
# [nltk_data]    | Downloading package mwa_ppdb to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping misc\mwa_ppdb.zip.
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\names.zip.
# [nltk_data]    | Downloading package nombank.1.0 to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\nonbreaking_prefixes.zip.
# [nltk_data]    | Downloading package nps_chat to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nps_chat is already up-to-date!
# [nltk_data]    | Downloading package omw to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\opinion_lexicon.zip.
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package paradigms to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\paradigms.zip.
# [nltk_data]    | Downloading package pe08 to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\pe08.zip.
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping misc\perluniprops.zip.
# [nltk_data]    | Downloading package pil to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\pil.zip.
# [nltk_data]    | Downloading package pl196x to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\pl196x.zip.
# [nltk_data]    | Downloading package porter_test to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping stemmers\porter_test.zip.
# [nltk_data]    | Downloading package ppattach to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\ppattach.zip.
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\problem_reports.zip.
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\product_reviews_1.zip.
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\product_reviews_2.zip.
# [nltk_data]    | Downloading package propbank to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package pros_cons to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\pros_cons.zip.
# [nltk_data]    | Downloading package ptb to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\ptb.zip.
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package qc to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\qc.zip.
# [nltk_data]    | Downloading package reuters to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package rslp to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping stemmers\rslp.zip.
# [nltk_data]    | Downloading package rte to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\rte.zip.
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping grammars\sample_grammars.zip.
# [nltk_data]    | Downloading package semcor to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package senseval to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\senseval.zip.
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\sentence_polarity.zip.
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\sentiwordnet.zip.
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\shakespeare.zip.
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\sinica_treebank.zip.
# [nltk_data]    | Downloading package smultron to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\smultron.zip.
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping grammars\spanish_grammars.zip.
# [nltk_data]    | Downloading package state_union to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\state_union.zip.
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\subjectivity.zip.
# [nltk_data]    | Downloading package swadesh to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\swadesh.zip.
# [nltk_data]    | Downloading package switchboard to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\switchboard.zip.
# [nltk_data]    | Downloading package tagsets to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping help\tagsets.zip.
# [nltk_data]    | Downloading package timit to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\timit.zip.
# [nltk_data]    | Downloading package toolbox to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\toolbox.zip.
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\treebank.zip.
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\twitter_samples.zip.
# [nltk_data]    | Downloading package udhr to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\udhr.zip.
# [nltk_data]    | Downloading package udhr2 to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\udhr2.zip.
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\unicode_samples.zip.
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping taggers\universal_tagset.zip.
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package verbnet to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\verbnet.zip.
# [nltk_data]    | Downloading package verbnet3 to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\verbnet3.zip.
# [nltk_data]    | Downloading package webtext to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\webtext.zip.
# [nltk_data]    | Downloading package wmt15_eval to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping models\wmt15_eval.zip.
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping models\word2vec_sample.zip.
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package wordnet2022 to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\wordnet2022.zip.
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\wordnet_ic.zip.
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\words.zip.
# [nltk_data]    | Downloading package ycoe to
# [nltk_data]    |     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\ycoe.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
text1
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %%
text = " ".join(text7)
text_corrected = " ".join(word for word in text7 if word.isalpha())
word_list = nltk.word_tokenize(text_corrected)

# %%
freq_dist = FreqDist(word_list)
hapaxes = freq_dist.hapaxes()
low_freq_words = [word for word, freq in freq_dist.items() if freq < 5]
print("Слова-унікаліними (hapaxes):", hapaxes)
print("Слова, які зустрічаються менше 5 разів:", low_freq_words)
# Out:
# Слова-унікаліними (hapaxes): ['Pierre', 'Elsevier', 'Agnew', 'fiber', 'resilient', 'lungs', 'symptoms', 'Loews', 'Micronite', 'spokewoman', 'properties', 'filter', 'Four', 'diagnosed', 'malignant', 'mesothelioma', 'asbestosis', 'morbidity', 'Groton', 'stringently', 'smooth', 'classified', 'amphobiles', 'Brooke', 'pathlogy', 'Vermont', 'curly', 'Environmental', 'Protection', 'gradual', 'outlawed', 'Areas', 'dusty', 'burlap', 'sacks', 'bin', 'poured', 'cotton', 'acetate', 'mechanically', 'clouds', 'dust', 'hung', 'ventilated', 'Darrell', 'Yields', 'tracked', 'IBC', 'fraction', 'Compound', 'reinvestment', 'lengthened', 'longest', 'Donoghue', 'Longer', 'Shorter', 'Brenda', 'Malizia', 'Negus', 'rises', 'pour', 'Assets', 'Dreyfus', 'invests', 'waiving', 'Bolduc', 'Terrence', 'Daniels', 'Royal', 'Trustco', 'McDermott', 'Babcock', 'Wilcox', 'Wickliffe', 'computerized', 'Legislation', 'ensnarled', 'earliest', 'Clark', 'oversee', 'biannual', 'powwow', 'titans', 'sunny', 'confines', 'Hoosier', 'royalty', 'rock', 'buckle', 'Rust', 'rusty', 'Maytag', 'lesser', 'knowns', 'Trojan', 'Queen', 'Cheese', 'starters', 'Hudnut', 'Symphony', 'Orchestra', 'guest', 'Borge', 'dessert', 'escort', 'busloads', 'wives', 'raced', 'Speedway', 'unimpeded', 'traffic', 'lieutenant', 'breakfast', 'drinks', 'everyday', 'speedway', 'hauled', 'crews', 'Fortune', 'drooled', 'schoolboys', 'dummies', 'Back', 'execs', 'boarding', 'dancing', 'moons', 'renovated', 'Roof', 'ballroom', 'hottest', 'duckling', 'mousseline', 'lobster', 'consomme', 'veal', 'mignon', 'chocolate', 'terrine', 'raspberry', 'sauce', 'Knowing', 'tasty', 'eat', 'ovation', 'tempts', 'heartland', 'winter', 'sluggishness', 'Preliminary', 'tallies', 'cloud', 'Exports', 'gloomy', 'accumulated', 'Post', 'discounts', 'fixtures', 'underscore', 'Mortimer', 'Zuckerman', 'guaranteed', 'subscriber', 'Circulation', 'awards', 'renewal', 'shore', 'Publishers', 'giveaways', 'subscribers', 'telephones', 'Audit', 'Circulations', 'newsweekly', 'payoff', 'Westborough', 'Manchester', 'efficiencies', 'evaluated', 'emerges', 'attracts', 'Wilbur', 'Rothschild', 'cluttered', 'Regulatory', 'refile', 'expedited', 'FERC', 'Ricken', 'Toys', 'R', 'Us', 'Deane', 'Signet', 'Rexinger', 'Glauber', 'ratepayers', 'overruns', 'entertain', 'pool', 'hostage', 'slash', 'tracking', 'addresses', 'nightmare', 'disputed', 'collecting', 'refunded', 'calculations', 'differential', 'Appellate', 'LaSalle', 'Automobile', 'setting', 'arising', 'consumption', 'Chinchon', 'diversifying', 'fledgling', 'depend', 'longevity', 'Documents', 'scrapped', 'operational', 'prototype', 'needing', 'promissory', 'complicate', 'tricky', 'unproven', 'gallium', 'arsenide', 'robotic', 'twice', 'Hitachi', 'existed', 'Regarded', 'Davenport', 'Blanchard', 'Hammerton', 'Wheeland', 'Pardus', 'Carney', 'Tassinari', 'diplomacy', 'watching', 'copyrights', 'India', 'investigations', 'genuine', 'touchy', 'denial', 'harms', 'inventiveness', 'offending', 'citizens', 'protections', 'discouraging', 'deterring', 'lauded', 'pirates', 'initialing', 'amending', 'trademark', 'unauthorized', 'showings', 'compel', 'parlors', 'enact', 'compatible', 'literary', 'Greece', 'Hoffman', 'specializing', 'retaliation', 'improvements', 'craft', 'developments', 'piracy', 'disregard', 'halve', 'declaration', 'Economy', 'Nestor', 'Latin', 'aspires', 'external', 'Miguel', 'Alurralde', 'Assistant', 'Mulford', 'negotiator', 'Carballo', 'Menem', 'centennial', 'milestones', 'THREE', 'COMPUTERS', 'THAT', 'CHANGED', 'Commodore', 'Pet', 'Tandy', 'audiocassettes', 'garage', 'Wozniak', 'Jobs', 'hobbyists', 'Homebrew', 'Club', 'affordable', 'explosive', 'desktop', 'mainframe', 'Altair', 'Sol', 'IMSAI', 'keyboards', 'contributors', 'billionaire', 'adapted', 'Shugart', 'Seagate', 'Hayes', 'Dale', 'Heatherington', 'modems', 'Purepac', 'label', 'Strait', 'Broken', 'Output', 'gradually', 'reaches', 'Perch', 'Dolphin', 'Seahorse', 'Tarwhine', 'Sloan', 'Following', 'gelatin', 'capsules', 'divest', 'possessions', 'Gener ...
# Слова, які зустрічаються менше 5 разів: ['Pierre', 'Vinken', 'join', 'Elsevier', 'Dutch', 'Rudolph', 'Agnew', 'Consolidated', 'Gold', 'Fields', 'conglomerate', 'cigarette', 'exposed', 'fiber', 'unusually', 'resilient', 'enters', 'lungs', 'exposures', 'symptoms', 'decades', 'Loews', 'Micronite', 'appear', 'forum', 'spokewoman', 'talking', 'heard', 'questionable', 'properties', 'aware', 'smokers', 'useful', 'users', 'Talcott', 'Cancer', 'Harvard', 'modest', 'filter', 'died', 'Four', 'surviving', 'diagnosed', 'malignant', 'mesothelioma', 'lung', 'asbestosis', 'morbidity', 'striking', 'Groton', 'industrialized', 'Hollingsworth', 'Vose', 'regulate', 'stringently', 'chrysotile', 'buildings', 'regulation', 'smooth', 'fibers', 'classified', 'amphobiles', 'Brooke', 'Mossman', 'pathlogy', 'Vermont', 'curly', 'body', 'explained', 'Environmental', 'Protection', 'imposed', 'gradual', 'outlawed', 'Areas', 'dusty', 'Workers', 'dumped', 'burlap', 'sacks', 'imported', 'bin', 'poured', 'cotton', 'acetate', 'mechanically', 'dry', 'clouds', 'dust', 'hung', 'exhaust', 'fans', 'ventilated', 'contracted', 'Darrell', 'Phillips', 'human', 'recognize', 'events', 'bearing', 'Yields', 'amid', 'compound', 'taxable', 'tracked', 'IBC', 'eased', 'fraction', 'Compound', 'assume', 'reinvestment', 'maturity', 'lengthened', 'longest', 'Donoghue', 'Longer', 'maturities', 'indicate', 'declining', 'permit', 'retain', 'Shorter', 'capture', 'sooner', 'indicator', 'Nevertheless', 'Brenda', 'Malizia', 'Negus', 'blip', 'rises', 'pour', 'Assets', 'grew', 'Typically', 'comparable', 'vary', 'Dreyfus', 'Dollar', 'invests', 'waiving', 'boosts', 'simple', 'slid', 'Bolduc', 'Grace', 'holds', 'succeeds', 'Terrence', 'Daniels', 'formerly', 'Royal', 'Trustco', 'obtain', 'McDermott', 'Babcock', 'Wilcox', 'Bailey', 'Controls', 'Operations', 'Finmeccanica', 'Italian', 'mechanical', 'Wickliffe', 'computerized', 'controls', 'employs', 'lifted', 'acts', 'obligations', 'borrowing', 'midnight', 'Legislation', 'lift', 'ensnarled', 'fight', 'taxes', 'earliest', 'Clark', 'Vitulli', 'arm', 'Mazda', 'oversee', 'Previously', 'biannual', 'powwow', 'titans', 'typically', 'jet', 'sunny', 'confines', 'resort', 'towns', 'Boca', 'Raton', 'Hot', 'Springs', 'Manufacturers', 'Hoosier', 'Indianapolis', 'treat', 'guests', 'royalty', 'rock', 'stars', 'owners', 'buckle', 'Rust', 'Belt', 'rusty', 'receiving', 'message', 'giants', 'Du', 'Pont', 'Maytag', 'lesser', 'knowns', 'Trojan', 'Queen', 'Cheese', 'Factory', 'starters', 'joined', 'Mayor', 'Hudnut', 'III', 'evening', 'Symphony', 'Orchestra', 'guest', 'Victor', 'Borge', 'Champagne', 'dessert', 'morning', 'escort', 'busloads', 'wives', 'raced', 'Speedway', 'unimpeded', 'traffic', 'red', 'lights', 'governor', 'lieutenant', 'welcomed', 'buffet', 'breakfast', 'museum', 'drinks', 'banned', 'everyday', 'visitors', 'speedway', 'hauled', 'drivers', 'crews', 'exhibition', 'race', 'Fortune', 'drooled', 'schoolboys', 'dummies', 'pointed', 'machines', 'sponsor', 'Back', 'downtown', 'execs', 'squeezed', 'hotel', 'boarding', 'buses', 'dinner', 'dancing', 'moons', 'renovated', 'Roof', 'ballroom', 'hottest', 'chefs', 'town', 'fed', 'duckling', 'mousseline', 'lobster', 'consomme', 'veal', 'mignon', 'chocolate', 'terrine', 'raspberry', 'sauce', 'Knowing', 'tasty', 'meal', 'eat', 'ovation', 'CEOs', 'tempts', 'heartland', 'forward', 'winter', 'February', 'reflecting', 'sluggishness', 'released', 'Preliminary', 'tallies', 'Industry', 'setback', 'casting', 'cloud', 'Exports', 'mere', 'boom', 'prolonged', 'disputes', 'conflicts', 'Government', 'gloomy', 'recorded', 'surplus', 'accumulated', 'Imports', 'incentive', 'Post', 'Plans', 'discounts', 'maintaining', 'permanent', 'fixtures', 'weeklies', 'underscore', 'fierce', 'Warner', 'Mortimer', 'Zuckerman', 'Alan', 'Spoon', 'lowered', 'guaranteed', 'effectively', 'subscriber', 'announce', 'Circulation', 'Credit', 'Plan', 'awards', 'credits', 'renewal', 'reward', 'bonuses', 'exceed', 'shore', 'Publishers', 'Information', 'Bureau', 'm ...

# %%
word_lengths = [len(word) for word in word_list]

length_freq_dist = FreqDist(word_lengths)

sorted_keys = sorted(length_freq_dist.keys())
sorted_values = [length_freq_dist[key] for key in sorted_keys]

plt.plot(sorted_keys, sorted_values)
plt.xticks(range(min(sorted_keys), max(sorted_keys)+1))
plt.xlabel('Довжина слова')
plt.ylabel('Частота')
plt.title('Графік довжини слів до їх частоти')

plt.show()

# %%
sent_list = nltk.sent_tokenize(text)
auxilliary_matrix = [[word for word in nltk.word_tokenize(sentence) if word.isalpha() and word != 'T'and word != 'U'] for sentence in sent_list]
last_words = [auxilliary_matrix[i][-1] for i in range(len(auxilliary_matrix)) if auxilliary_matrix[i] != []]
freq_dist_last_words = FreqDist(last_words)
freq_dist_last_words.most_common(10)
# Out:
# [('said', 106),
#  ('million', 51),
#  ('to', 50),
#  ('says', 39),
#  ('year', 38),
#  ('in', 35),
#  ('share', 34),
#  ('trading', 30),
#  ('it', 28),
#  ('billion', 24)]

# %%
f=open('book.txt', 'r', encoding='UTF-8')
raw = f.read( )
tokens = nltk.word_tokenize(raw)
text_king = nltk.Text(tokens)

# %%
text_king.concordance('affliction')
# Out:
# Displaying 25 of 26 matches:
# ent , over and above the conjugal affliction with which it invaded the lady ’
# derate expressions of anguish and affliction , and , while his delirium lasted
# n Teresa could no longer keep her affliction within bounds . Indeed , this was
#  acquainted with the cause of his affliction . Instead of gratifying her reque
# cause his heart was melted by her affliction , and next day condescended to ac
# ho sincerely sympathised with his affliction , would have persuaded him to ret
#  had laboured under some grievous affliction ; and though the first transports
# o sooner learned the cause of her affliction , than he presented her with his
# y and guilt . As for Fathom , his affliction was unutterable , when he found h
# o more ; and , what aggravates my affliction for the loss of such a father , i
# al from Monimia the extent of his affliction . The money-broker whom he employ
#  to make himself necessary to her affliction , and settle a gossiping correspo
#  , to raise her from distress and affliction , to that honour and felicity for
# th manifest marks of disorder and affliction . Indeed , his confusion was in s
# l sentiments of humanity . Common affliction was an agreeable reverie to what
# to alleviate , if possible , that affliction which was manifest in her looks .
# source of all his misfortunes and affliction . He thanked Heaven for having bl
# on in his favour ; and the air of affliction , so remarkable in his visage , d
#  and resolved to live in spite of affliction . Thus determined , I betook myse
# rate the excess of his friend ’ s affliction . Though it was dark when they al
# such a degree of impatience is my affliction whetted , that no slumber shall a
# ion sore with the galling hand of affliction ; and , turning up his eyes to He
#  practised during the term of her affliction . And , lastly , they were accost
# verwhelmed us all with the utmost affliction . Antonia lamented , without ceas
# ve so long in obscurity . And her affliction derived new force from the death

# %%
print("\nWords similar to 'affliction':")
text_king.similar('affliction')
# Out:
# Words similar to 'affliction':
# distress affection life virtue heart mind love gallantry passion
# friendship fear beauty care humanity family countenance satisfaction
# success address friends

# %%
words_king = ['light', 'bad', 'darkness']
text_king.dispersion_plot(words_king)

# %%
freq_dist_king = nltk.FreqDist(text_king)
hapaxes_king = freq_dist_king.hapaxes()
hapaxes_king
# Out:
# ['Title',
#  'T.',
#  'Release',
#  '9',
#  '2004',
#  '#',
#  '6761',
#  'recently',
#  'updated',
#  'October',
#  '2022',
#  'Language',
#  'Credits',
#  'Tapio',
#  'Riikonen',
#  'David',
#  'Widger',
#  'CONTENTS',
#  'Observations',
#  'View',
#  'Infancy',
#  'Patron',
#  'Prowess',
#  'Sagacity',
#  'brief',
#  'Detail',
#  'Education',
#  'meditates',
#  'Schemes',
#  'Importance',
#  'Engages',
#  'Partnership',
#  'Talents',
#  'Action',
#  'Digression',
#  'Readers',
#  'Confederates',
#  'achieve',
#  'Adventure',
#  'levy',
#  'enters',
#  'League',
#  'Gallantry',
#  'Lodgment',
#  'House',
#  'Jeweller',
#  'Incident',
#  'Course',
#  'Intrigue',
#  'Daughter',
#  'Dilemma',
#  'Assignation',
#  'Wife',
#  'succeeds',
#  'begets',
#  'Security',
#  'Apartment',
#  'Step-dame',
#  'Suspicions',
#  'Snare',
#  'Genius',
#  'departs',
#  'quits',
#  'Domain',
#  'Venus',
#  'Field',
#  'Guidance',
#  'stumbles',
#  'Camp',
#  'finishes',
#  'Career',
#  'prepares',
#  'Stratagem',
#  'countermined—Proceeds',
#  'Journey',
#  'Tempest',
#  'arrives',
#  'Reception',
#  'Acquits',
#  'Address',
#  'Nocturnal',
#  'Riot',
#  'overlooks',
#  'Advances',
#  'Friends',
#  'smarts',
#  'Neglect',
#  'Fate',
#  'Philosopher',
#  'contracts',
#  'Noble',
#  'Instance',
#  'Retreat',
#  'Fellow-Travellers',
#  'Deliverance',
#  'Effects',
#  'Smuggler',
#  'Conjecture',
#  'Attack',
#  'Triumph',
#  'Conference',
#  'Treaty',
#  'Applause',
#  'Admiration',
#  'Biter',
#  'Bit',
#  'contemplates',
#  'Satellites',
#  'Quarrel',
#  'Arms',
#  'Rencontre',
#  'Revolution',
#  'Affairs',
#  'Distress',
#  'deepens',
#  'Plot',
#  'thickens',
#  'Passions',
#  'Aim',
#  'Art',
#  'Borrowing',
#  'Strange',
#  'Phenomenon',
#  'unmasks',
#  'repulsed',
#  'Operations',
#  'Honour',
#  'shifts',
#  'Character',
#  'Triumphs',
#  'Medical',
#  'Rival',
#  'Repairs',
#  'Metropolis',
#  'enrols',
#  'Sons',
#  'Acquires',
#  'Employment',
#  'Miscarriage',
#  'Declination',
#  'Matrimonial',
#  'Noose',
#  'strangled',
#  'Retrospect',
#  'abridges',
#  'Proceedings',
#  'Law',
#  'approves',
#  'Son',
#  'Messenger',
#  'Happiness',
#  'Sister',
#  'removes',
#  'Penetration',
#  'recompenses',
#  'Attachment',
#  'receives',
#  'Letter',
#  'reduces',
#  'Verge',
#  'Distraction',
#  'Monument',
#  'Justice',
#  'Note',
#  'Midnight',
#  'Pilgrimage',
#  'Tomb',
#  'Rites',
#  'Sorrow',
#  'Mystery',
#  'unfolded—Another',
#  'Recognition',
#  'Link',
#  'Concatenation',
#  'draws',
#  'Period',
#  'Longest',
#  'Last',
#  'ILLUSTRATIONS',
#  'Opened',
#  'Repository',
#  '1753',
#  'Wortley',
#  'Montagu',
#  'Bute',
#  'January',
#  '1st',
#  '1755',
#  'remarked',
#  'flags',
#  'work.',
#  'inventive',
#  'realistic',
#  'comparatively',
#  'relatively',
#  'vigorous',
#  'personality',
#  'gibbet',
#  'individuality—the',
#  'described—is',
#  'revelation',
#  'invention.',
#  'Subsequently',
#  'denying',
#  'displays',
#  'Unfortunately',
#  'thorough-going',
#  'uninteresting',
#  'contemporary',
#  'reveals',
#  'rambling',
#  'storyteller',
#  'rational',
#  'unromantic',
#  'oddly-metamorphosed',
#  'experiences',
#  'forerunner',
#  'organic',
#  'notably',
#  'surprises',
#  'comparative',
#  'lifelessness',
#  'galore',
#  'Georgian',
#  'life-like',
#  'exception',
#  'hardened',
#  'camp-follower',
#  'vitalised',
#  'partially',
#  'characteristic',
#  'lucrative',
#  'unfeelingly',
#  'non-fulfilment',
#  'label',
#  'Because',
#  'placarded',
#  'Shrewd',
#  'creator',
#  'convincingly',
#  'high-minded',
#  'saint-like',
#  'foolish',
#  'Neither',
#  'vitality',
#  'throbbing',
#  'heroines',
#  'melodrama',
#  'vivified',
#  'mostly',
#  'inanimate',
#  'strikingly',
#  'development',
#  'unreal',
#  'villainies',
#  'perpetrates',
#  'Matthew',
#  'Bramble',
#  'Esq.',
#  'consistently',
#  'cold-blooded',
#  'roguery',
#  'scoundrel',
#  'develops',
#  'parallel',
#  'originality',
#  'Only',
#  'lacks',
#  'infrequently',
#  'well-conceived',
#  'divertingly',
#  'thoroughly',
#  'structure',
#  'clumsy',
#  'pensioner',
#  'irrelevant—such',
#  'history—is',
#  'romanticist',
#  'lends',
#  'blood-curdling',
#  'eighteenth-century',
#  'scores',
#  'jaded',
#  'trashy',
#  'reads',
#  'loft',
#  'technically',
#  'genuinely',
#  'castle-tower',
#  'waves',
#  'would-be',
#  'rescuer',
#  'lady-love',
#  'grave-yard',
#  'poets—that',
#  'W.',
#  'L.',
#  'Phelps',
#  'Night',
#  'Thoughts',
#  'exemplar',
#  '—that',
#  'poking',
#  'context',
#  'Walpole',
#  'Otranto',
#  'connection',
#  'Dickens',
#  'rescues',
#  'ups',
#  'downs',
#  'petted',
#  'chronicling',
#  'meteoric',
#  'Thackeray',
#  'harping',
#  'century—',
#  'recognition.',
#  'Dr.',
#  'rapidly',
#  'carriage.',
#  'dishonest.',
#  'Apart',
#  'detective-stories',
#  'student',
#  'showing',
#  'tendencies',
#  'MAYNADIER',
#  'self-complacency',
#  'impracticable.—Indeed',
#  'differed',
#  'predominancy',
#  'warp',
#  'judicious',
#  'enumeration',
#  'prostituted',
#  'exaggerate',
#  'ascribe',
#  'pours',
#  'Maecenas',
#  'gives',
#  'involves',
#  'Seasons',
#  'undeserved',
#  'incense',
#  'popular',
#  'retract',
#  'prematurely',
#  'stigmatise',
#  'name—a',
#  'poetical',
#  'dedicators',
#  'ostentation.—I',
#  'awkwardly',
#  'haughty',
#  'resentments',
#  'coarse',
#  'conduct—yet',
#  'overbalance',
#  'defects',
#  'faults',
#  'excesses',
#  'control',
#  'stimulated',
#  'censorious',
#  'unwind',
#  'desert.—Yet',
#  'remuneration',
#  'wavers',
#  'enables',
#  'preponderate',
#  'drama',
#  'Richard',
#  'Maskwell',
#  'Bevil',
#  'Edward',
#  'impulses',
#  'purlieus',
#  'plunging',
#  'instruct',
#  'springs',
#  'branded',
#  'reader—circumstances',
#  'AUTHOR',
#  'SAGE',
#  'OBSERVATIONS',
#  'NATURALLY',
#  'INTRODUCE',
#  'IMPORTANT',
#  'Retz',
#  'judiciously',
#  'historians',
#  'rarely',
#  'portraits',
#  'phantasy',
#  'mists',
#  'peruses',
#  'self-approbation',
#  'Supposing',
#  'historical',
#  'pens',
#  'ancients',
#  'transmitting',
#  'sheets',
#  'historian',
#  'chivalry',
#  'consecrated',
#  'patrimony',
#  'reckon',
#  'tendernesses',
#  'fabulous',
#  'disown',
#  'promising',
#  'begotten',
#  'particularities',
#  'determining',
#  'ascertaining',
#  'contested',
#  'birthplace',
#  'Homer',
#  'Englishwoman',
#  'Marlborough',
#  'allied',
#  'Geneva',
#  'liberally',
#  'imaginations',
#  'obscene',
#  'Must',
#  'grovelling',
#  'Will',
#  'connoisseurs',
#  'purifications',
#  'evaporate',
#  'polish',
#  'sapience',
#  'flavours',
#  'delectation',
#  'clime',
#  'precedent',
#  'Petronius',
#  'Arbiter',
#  'Ovid',
#  'chuckle',
#  'Lucian',
#  'ass',
#  'presumes',
#  'Guzman',
#  'Alfarache',
#  'beggary',
#  'strollers',
#  'Gil',
#  'Blas',
#  'Swift',
#  'Pope',
#  'represents',
#  'coxcomb',
#  'reputed',
#  'expletives',
#  'explore',
#  'jakes',
#  'Rabelais',
#  'dean',
#  'dressing-room',
#  'unstamped',
#  'noses',
#  'chamber-pot',
#  'Catullus',
#  'Juvenal',
#  'Persius',
#  'Lucan',
#  'lashing',
#  'satirist',
#  'pseudo-patron',
#  'accuse',
#  'scurrility',
#  'ennobled',
#  'dares',
#  'castigated',
#  'changeling',
#  'slavers',
#  'grin',
#  'volatilised',
#  'manna',
#  'soul-sweetening',
#  'SUPERFICIAL',
#  'VIEW',
#  'INFANCY',
#  'bespoken',
#  'teems',
#  'occupations',
#  'conveniently',
#  'suckle',
#  'firstborn',
#  'nursing',
#  'she-wolf',
#  'foster',
#  'energetic',
#  'nectar',
#  'cask',
#  'zone',
#  'knapsack',
#  'balanced',
#  'keg',
#  'flexible',
#  'tube',
#  'stilled',
#  'sucking',
#  'mix',
#  'marvellous',
#  'narrations',
#  'infant',
#  'discompose',
#  'constitutions',
#  'hardy',
#  'potation',
#  'diluted',
#  'rejecting',
#  'dangled',
#  'transiently',
#  'silken',
#  'drum-head',
#  'thenceforward',
#  'Fadom',
#  'natale',
#  'solum',
#  'vocation',
#  'oaths',
#  'earliest',
#  'cook',
#  'regimental',
#  'suttling-tent',
#  'apace',
#  'Hercules',
#  'whiskers',
#  'suck',
#  'impregnated',
#  'gunpowder',
#  'touch-hole',
#  'serjeants',
#  'Prague',
#  'cabaret',
#  'Scotch',
#  'vernacular',
#  'soliloquies',
#  're-enjoying',
#  'emoluments',
#  'INITIATED',
#  'ACQUIRE',
#  'GENEROUS',
#  'PATRON',
#  'wearied',
#  'petitions',
#  'Ottoman',
#  'housekeeping',
#  'merchandised',
#  'Turkey',
#  'initiating',
#  'rudiments',
#  'Turks',
#  'distressing',
#  'poignard',
#  'annoy',
#  'threescore',
#  'Mussulmen',
#  'compassionately',
#  'infidels',
#  'ejaculation',
#  'resolve',
#  'power.',
#  'Agreeably',
#  'countrywoman',
#  'espying',
#  'Temiswaer',
#  'providentially',
#  'plenty',
#  'embracing',
#  'soldiery',
#  'befriending',
#  'revisiting',
#  'MOTHER',
#  'PROWESS',
#  'TOGETHER',
#  'INSTANCES',
#  'SAGACITY',
#  'big',
#  're-acting',
#  'advantage.—Nay',
#  'inherent',
#  'inspiring',
#  'veteran',
#  'exploit',
#  'flank',
#  'turbans',
#  'chiefs',
#  'agas',
#  'leader',
#  'trappings',
#  'musket-ball',
#  'symitar',
#  'she-campaigner',
#  'writhing',
#  'Camilla',
#  'semicircle',
#  'attacking',
#  'well-tried',
#  'life-blood',
#  'prone',
#  'Allah',
#  'followers',
#  'reel',
#  'autumn',
#  'shout',
#  'right-about',
#  'clapping',
#  'Austrians',
#  'Arabian',
#  'first-fruits',
#  'enticed',
#  'glittering',
#  'caparisons',
#  'forelock',
#  'hazards',
#  'ermine',
#  'bundle',
#  'desperately',
#  'stalked',
#  'Atropos',
#  'wherever',
#  'perdue',
#  'covert',
#  'crescent',
#  'cupidity',
#  'thitherward',
#  'discharging',
#  'Semiramis',
#  'Tomyris',
#  'Zenobia',
#  'boasted',
#  'ninth',
#  'docility',
#  'planted',
#  'bias',
#  'determinations',
#  'pallet',
#  'field-bed',
#  'prattle',
#  'incredibly',
#  'neglecting',
#  'sedate',
#  'anticipating',
#  'uncovered',
#  'prayer',
#  'sentry',
#  'wisdom',
#  'BRIEF',
#  'DETAIL',
#  'EDUCATION',
#  'Passarowitz',
#  'suitably',
#  'bits',
#  'superintend',
#  'imbibe',
#  'lads',
#  'discernible',
#  'dissimilarity',
#  'rivalship',
#  'interrupts',
#  'athletic',
#  'fellow-scholars',
#  'dunce',
#  'dancing-master',
#  'bows',
#  'pawings',
#  'mule',
#  'sheep-stealer',
#  'monosyllables',
#  'negation',
#  'unaltered',
#  'superiority',
#  'compliances',
#  'womb',
#  'superstructure',
#  'yoked',
#  'ductility',
#  'appetites',
#  'levying',
#  'instructors',
#  'capacities',
#  'tutelage',
#  'generosity.—The',
#  'overt',
#  'illustration',
#  'injudicious',
#  'decisions',
#  'pedagogue',
#  'tasks',
#  'Commentaries',
#  'insert',
#  'text',
#  'verbatim',
#  'heap',
#  'bestowing',
#  'sameness',
#  'chastising',
#  'murmuring',
#  'boldly',
#  'nettled',
#  'flogger',
#  'ambiguous',
#  'plagiary',
#  'inhospitality',
#  'allegation',
#  'selfishness',
#  'encourage',
#  'husk',
#  'exhibition',
#  'conceiving',
#  'misconstruction',
#  'soars',
#  'misinterpretation',
#  'twelfth',
#  'puerility',
#  'elapse',
#  'school-education',
#  'skim',
#  'pool',
#  'wet',
#  'unsuited',
#  'fives',
#  'billiards',
#  'MEDITATES',
#  'SCHEMES',
#  'IMPORTANCE',
#  'older',
#  'obsequious',
#  'promote',
#  'greenness',
#  'fallacious',
#  'Observing',
#  'flute',
#  'proficient',
#  'sixteen',
#  'effectuated',
#  'tempered',
#  'blasting',
#  'blossomed',
#  'gaily',
#  'Restricted',
#  'sap',
#  'haughtiness',
#  'devised',
#  'reproofs',
#  'sparingly',
#  'levelling',
#  'swains',
#  'jocose',
#  'faltered',
#  'pride.—Baffled',
#  'prolonged',
#  'ministered',
#  'diagnostics',
#  'secundum',
#  'artem',
#  'blooded',
#  'purged',
#  'blistered',
#  'dispensary',
#  'bolusses',
#  'apozems',
#  'cope',
#  'unaccomplished',
#  'ENGAGES',
#  'PARTNERSHIP',
#  'PUT',
#  'TALENTS',
#  'ACTION',
#  'senior',
#  'unquestionably',
#  'stock',
#  'premised',
#  'sooth',
#  'strives',
#  'mistress.—She',
#  'foresight',
#  'unapt',
#  'schools',
#  'self-taught',
#  'invention.—He',
#  'ablest',
#  'statesmen',
#  'love-sick',
#  'convince',
#  'incapacity',
#  'clandestinely',
#  'alluring',
#  'latitudinarian',
#  'disapproving',
#  'flaw',
#  'disavow',
#  'strictly',
#  'subscribing',
#  'righteousness',
#  'waived',
#  'clergymen',
#  'ecclesiastics',
#  'she-adventurer',
#  'readily',
#  'preposterous',
#  'covenant',
#  'conjuration',
#  'cement',
#  'reversionary',
#  'FIRST',
#  'DIGRESSION',
#  'READERS',
#  'THINK',
#  'IMPERTINENT',
#  'voluptuaries',
#  'constantly',
#  'feign',
#  'irritated',
#  'revilings',
#  'unpractised',
#  'sown',
#  'luxuriant',
#  'cultured',
#  'looser',
#  'ingrafted',
#  'inflammability',
#  'sourness',
#  'Prepared',
#  'depreciate',
#  'consist',
#  'calumnies',
#  'vented',
#  'dispraise',
#  'traduced',
#  'habitually',
#  'self-respect',
#  'reaping',
#  'irreverence',
#  'dudgeon',
#  'appellant',
#  'condemner',
#  'furiously',
#  'patronising',
#  'sarcasm',
#  'Zoilus',
#  'blemishes',
#  'pronounce',
#  'beauties',
#  'decried',
#  'rejoinder',
#  'disrespect',
#  'superficially',
#  'perusing',
#  'dependants',
#  'thread',
#  'imply',
#  'exemplifying',
#  'pertness',
#  'arrogance',
#  'blaming',
#  'well-instructed',
#  'furtherance',
#  'freer',
#  'lowering',
#  'sensualists',
#  'whetting',
#  'chocolate',
#  'provocations',
#  'fulfilling',
#  'foundations',
#  'conspirators',
#  'misconstructions',
#  'impudence',
#  'CONFEDERATES',
#  'CHANGE',
#  'ACHIEVE',
#  'ADVENTURE',
#  'Thunderstruck',
#  'conveniency',
#  'prudent',
#  'hay',
#  'defrauding',
#  'embezzling',
#  'wench',
#  'appropriate',
#  'conformity',
#  'finder',
#  'escritoir',
#  'demeaned',
#  'medal',
#  'well-acted',
#  'fear.',
#  'exempting',
#  'replying',
#  'negative',
#  'Abigail',
#  'sisterhood',
#  'menace',
#  'untold',
#  'mean-spirited',
#  'topsy-turvy',
#  'defame',
#  'ingenuously',
#  'men-servants',
#  'pardoned',
#  'entice',
#  'THEY',
#  'PROCEED',
#  'LEVY',
#  'CONTRIBUTIONS',
#  'UNTIL',
#  'SETS',
#  'YOUNG',
#  'ENTERS',
#  'INTO',
#  'LEAGUE',
#  'affirming',
#  'murdering',
#  'quieted',
#  'earrings',
#  'valued',
#  'recriminations',
#  'collusion',
#  'divulging',
#  'ushering',
#  'preceptor',
#  'precepts',
#  'reposing',
#  'dignifies',
#  'perceptions',
#  'tyrants',
#  'prowled',
#  'hungry',
#  'jackal',
#  'bush',
#  'voracious',
#  'fox',
#  'rust',
#  'building',
#  'fascinate',
#  'deceiving',
#  'endued',
#  'projection',
#  'economy.—',
#  'executive',
#  'league',
#  'pupils',
#  'pillage',
#  'provincials',
#  'likeness',
#  'alertness',
#  'offensive',
#  'defensive',
#  'MAKES',
#  'VARIOUS',
#  'GALLANTRY',
#  'hunt',
#  'couples',
#  'merry-making',
#  'fellow-pupils',
#  'absented',
#  'passdice',
#  'moralised',
#  'attachments',
#  'bastion',
#  'Port',
#  'Neuve',
#  'stripling',
#  'officiousness',
#  'spirited',
#  'shy',
#  'regularly',
#  'correspondent',
#  'seasons',
#  'adviser',
#  'conjunctures',
#  'Advice',
#  'improperly',
#  'diametrical',
#  'enterprises',
#  'obviate',
#  'tenacious',
#  'expressly',
#  'slights',
#  'humbler',
#  'LODGMENT',
#  'HOUSE',
#  'RICH',
#  'JEWELLER',
#  'conduce',
#  'bourgeois',
#  'humours',
#  'lass',
#  'disparity',
#  'ministering',
#  'intoxications',
#  'unenlightened',
#  ...]

# %%
import re


text = "first amount is $123.45, second amount is $400"


amounts = re.findall(r'\$[0-9]+(?:\.[0-9]{2})?', text)

amounts_float = [float(amount[1:]) for amount in amounts]
total_sum = sum(amounts_float)

print("Monetary amounts:", amounts_float)
print("Total sum:", total_sum)
# Out:
# Monetary amounts: [123.45, 400.0]
# Total sum: 523.45

# %%
import json
import re

initial_data = {
    "HTTPHost": "localhost",
    "HTTPPort": 8545,
    "Config": {
        "Enabled": True,
        "Server": "wakuv2.prod",
        "Nodes": [
            "8.210.222.231",
            "168.166.125.145",
            "192.168.0.1",
            "8.210.222.234",
            "8.210.222.588"
        ]
    }
}


with open('initial_data.json', 'w') as file:
    json.dump(initial_data, file, indent=4)

with open('initial_data.json', 'r') as file:
    data = json.load(file)

data['Config']['Nodes'] = [node for node in data['Config']['Nodes'] if not re.match(r'^8\.', node)]

server_name, server_type = re.match(r'(\w+)\.(\w+)', data['Config']['Server']).groups()
data['Config']['Server'] = {"name": server_name, "type": server_type}

with open('edited_data.json', 'w') as file:
    json.dump(data, file, indent=4)

# %%
import json

# Зчитування відредагованого JSON файлу
with open('edited_data.json', 'r') as file:
    edited_data = json.load(file)

# Виведення вмісту відредагованого JSON файлу
print(json.dumps(edited_data, indent=4))
# Out:
# {
#     "HTTPHost": "localhost",
#     "HTTPPort": 8545,
#     "Config": {
#         "Enabled": true,
#         "Server": {
#             "name": "wakuv2",
#             "type": "prod"
#         },
#         "Nodes": [
#             "168.166.125.145",
#             "192.168.0.1"
#         ]
#     }
# }
